# %%
#import necessary library
import pandas as pd

# %%
#read data from csv file fire department of New York City
df_fdny_csv_data_raw = pd.read_csv('C:\dataset\FDNY_Firehouse_Listing.csv')

# %%
#view content of data
df_fdny_csv_data_raw.describe
# Out:
# <bound method NDFrame.describe of                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                             Engine 6
# 2    Manhattan Borough Command/Battalion 1/Engine 7...
# 3                                             Ladder 8
# 4                                    Engine 9/Ladder 6
# ..                                                 ...
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                               Engine 151/Ladder 76
# 217                                         Engine 168
# 218                                           Marine 9
#
#               FacilityAddress        Borough  Postcode   Latitude  Longitude  \
# 0             42 South Street      Manhattan     10005  40.703694 -74.007717
# 1           49 Beekman Street      Manhattan     10038  40.709971 -74.005395
# ...

# %%
#view first five records
df_fdny_csv_data_raw.head(5)
# Out:
#                                         FacilityName     FacilityAddress  \
# 0                                 Engine 4/Ladder 15     42 South Street
# 1                                           Engine 6   49 Beekman Street
# 2  Manhattan Borough Command/Battalion 1/Engine 7...    100 Duane Street
# 3                                           Ladder 8  14 N. Moore Street
# 4                                  Engine 9/Ladder 6     75 Canal Street
#
#      Borough  Postcode   Latitude  Longitude  Community Board  \
# 0  Manhattan     10005  40.703694 -74.007717              101
# 1  Manhattan     10038  40.709971 -74.005395              101
# 2  Manhattan     10007  40.715339 -74.006300              101
# 3  Manhattan     10013  40.719574 -74.006620              101
# 4  Manhattan     10002  40.715408 -73.992834              103
#
#    Community Council   Census Tract      BIN         BBL  \
# 0                   1             7  1000867  1000350001
# ...

# %%
#skip the first row from dataset
df_fdny_csv_data = pd.read_csv('C:\dataset\FDNY_Firehouse_Listing.csv',skiprows=1)

# %%
#view first five records
df_fdny_csv_data_raw.head(5)
# Out:
#                                         FacilityName     FacilityAddress  \
# 0                                 Engine 4/Ladder 15     42 South Street
# 1                                           Engine 6   49 Beekman Street
# 2  Manhattan Borough Command/Battalion 1/Engine 7...    100 Duane Street
# 3                                           Ladder 8  14 N. Moore Street
# 4                                  Engine 9/Ladder 6     75 Canal Street
#
#      Borough  Postcode   Latitude  Longitude  Community Board  \
# 0  Manhattan     10005  40.703694 -74.007717              101
# 1  Manhattan     10038  40.709971 -74.005395              101
# 2  Manhattan     10007  40.715339 -74.006300              101
# 3  Manhattan     10013  40.719574 -74.006620              101
# 4  Manhattan     10002  40.715408 -73.992834              103
#
#    Community Council   Census Tract      BIN         BBL  \
# 0                   1             7  1000867  1000350001
# ...

# %%
#view data statistics using describe()
df_fdny_csv_data.describe()
# Out:
#               10005   40.703694  -74.007717         101           1  \
# count    218.000000  218.000000  218.000000  218.000000  218.000000
# mean   10794.844037   40.719587  -73.936431  290.114679   25.688073
# std      554.791540    0.083489    0.093360  126.674410   15.525628
# min    10001.000000   40.512739  -74.238950  101.000000    1.000000
# 25%    10305.000000   40.664263  -73.984150  203.000000   12.250000
# 50%    11153.000000   40.715373  -73.936858  306.000000   26.500000
# 75%    11232.750000   40.774282  -73.886600  405.000000   38.000000
# max    11695.000000   40.893028  -73.716081  503.000000   51.000000
#
#                    7       1000867    1000350001
# count     218.000000  2.180000e+02  2.180000e+02
# mean     5834.834862  2.923232e+06  2.867710e+09
# std     19360.030976  1.300148e+06  1.277982e+09
# min         1.000000  1.001287e+06  1.000520e+09
# 25%       129.250000  2.007899e+06  2.026968e+09
# 50%       279.500000  3.071000e+06  3.025125e+09
# ...

# %%
#view columns of the dataset
df_fdny_csv_data.columns
# Out:
# Index(['Engine 4/Ladder 15', '42 South Street', 'Manhattan', '10005',
#        '40.703694', '-74.007717', '101', '1', '7', '1000867', '1000350001',
#        'Battery Park City-Lower Manhattan'],
#       dtype='object')

# %%
#view index of dataset
df_fdny_csv_data.index
# Out:
# RangeIndex(start=0, stop=218, step=1)

# %%
#count number of records
df_fdny_csv_data.count()
# Out:
# Engine 4/Ladder 15                   218
# 42 South Street                      218
# Manhattan                            218
# 10005                                218
# 40.703694                            218
# -74.007717                           218
# 101                                  218
# 1                                    218
# 7                                    218
# 1000867                              218
# 1000350001                           218
# Battery Park City-Lower Manhattan    218
# dtype: int64

# %%
#view datatypes
df_fdny_csv_data.dtypes
# Out:
# Engine 4/Ladder 15                    object
# 42 South Street                       object
# Manhattan                             object
# 10005                                  int64
# 40.703694                            float64
# -74.007717                           float64
# 101                                    int64
# 1                                      int64
# 7                                      int64
# 1000867                                int64
# 1000350001                             int64
# Battery Park City-Lower Manhattan     object
# dtype: object

# %%
#select FDNY information boroughwise
groupby_borough = df_fdny_csv_data.groupby
